# %% [markdown]
# # Drinking Water Potability Project
#
# **Charles Serve-Catelin** - **Samuel Pujade** - **Mathieu Ract**

# %% [markdown]
# ## Récupération et Nettoyage des données

# %%
import project
from importlib import reload
reload(project)

project.avoid_warnings()
project.load_data("./data/drinking_water_potability.csv", disp=False)
project.display_explanatory_variables(disp=False)
project.check_null_values(disp=False)
project.cleaning_dataset()
project.delete_outliers()
# Out:
# Tue Oct 26 14:58:47 2021 : Warnings Suprimés
# Tue Oct 26 14:58:47 2021 : Données chargés
# Tue Oct 26 14:58:47 2021 : Données nulles trouvées
# Tue Oct 26 14:58:47 2021 : Données nulles remplacées
# (3276, 10)
# (3128, 10)
# Tue Oct 26 14:58:47 2021 : Données aberrantes remplacées

# %% [markdown]
# Commentaire :
#
# Bla Bla Bla

# %% [markdown]
# ## Analyse des données

# %% [markdown]
# #### Diagramme Moustache

# %%
project.boxplot()

# %% [markdown]
# Commentaire :
#
# Bla Bla Bla

# %% [markdown]
# #### Matrice de corrélation des variables

# %%
project.heatmap_corr()

# %% [markdown]
# Commentaire :
#
# Bla Bla Bla

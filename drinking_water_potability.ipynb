# %% [markdown]
# # Drinking Water Potability Project
#
# **Charles Serve-Catelin** - **Samuel Pujade** - **Mathieu Ract**

# %% [markdown]
# ## Récupération et Nettoyage des données

# %%
import project
from importlib import reload
reload(project)

project.avoid_warnings()
project.load_data("./data/drinking_water_potability.csv", disp=False)
project.display_explanatory_variables(disp=False)
project.check_null_values(disp=False)
project.cleaning_dataset()
project.delete_outliers()
# Out:
# Wed Oct 27 15:04:04 2021 : Warnings Suprimés
# Wed Oct 27 15:04:04 2021 : Données chargés
# Wed Oct 27 15:04:04 2021 : Données nulles trouvées
# Wed Oct 27 15:04:04 2021 : Données nulles remplacées
# Wed Oct 27 15:04:04 2021 : Données aberrantes remplacées

# %% [markdown]
# Commentaire :
#
# Bla Bla Bla

# %% [markdown]
# ## Analyse des données

# %% [markdown]
# #### Diagramme Moustache

# %%
project.boxplot()

# %% [markdown]
# Commentaire :
#
# Bla Bla Bla

# %% [markdown]
# #### Matrice de corrélation des variables

# %%
project.heatmap_corr()

# %% [markdown]
# Commentaire :
#
# Bla Bla Bla

# %% [markdown]
# ## Création du Train set et Test set

# %%
project.split_dataset(ratio=0.8, disp=False)
project.scaling_trainset()
# Out:
# Wed Oct 27 15:04:08 2021 : Dataset séparé
# Wed Oct 27 15:04:08 2021 : Trainset mis à l'echelle

# %% [markdown]
# ## Différents model de prédiction

# %%
project.fitting_KNN_model()
project.testing_KNN_model()

project.fitting_LR_model()
project.testing_LR_model()

project.fitting_RF_model()
project.testing_RF_model()

project.fitting_SVM_model()
project.testing_SVM_model()
# Out:
# Wed Oct 27 15:02:36 2021 : model KNN ajusté
# Wed Oct 27 15:02:37 2021 : model KNN testé
# Accuracy KNN : 62.46 %
#
# Wed Oct 27 15:02:37 2021 : model LR ajusté
# Wed Oct 27 15:02:37 2021 : model LR testé
# Accuracy LR : 64.38 %
#
# Wed Oct 27 15:02:39 2021 : model RF ajusté
# Wed Oct 27 15:02:39 2021 : model RF testé
# Accuracy RF : 68.53 %
#
# Wed Oct 27 15:02:41 2021 : model SVM ajusté
# Wed Oct 27 15:02:41 2021 : model SVM testé
# Accuracy RF : 69.17 %

# %% [markdown]
# Commentaire :
#
# The **Random Forest Classifier** and **Support Vector Machine** models seem to be the most accurate in their predictions.
